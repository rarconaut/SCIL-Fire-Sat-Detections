# %% [markdown]
# # Download VIIRS Heat Detection Data from WIFIRE Firemap
# ### What this notebook does:
#
# 1. Search for VIIRS heat detections by datetime range
# 2. Download all detection features from the WIFIRE Firemap Geoserver
# 3. Visualize heat detections on a Folium map
# 4. Save as JSON, CSV, and/or zipped Shapefile
#
#
# ### Data source:
#
# * WIFIRE Firemap - VIIRS heat detection data
# * Layer: view_viirs_iband
# * Contains actual mapped detections with timestamps
#
# ### Requirements:
#
# * Internet connection
# * Fire name
# * Fire start/stop datetimes

# %% [markdown]
# # Dependencies

# %%
import requests
import json
import sys
from datetime import datetime
import folium
import os

# %% [markdown]
# # Fire Data Collection

# %% [markdown]
# Testing the Geoserver API Query

# %%
# ========== USER INPUTS ==========

fire_name = "Border 2"  # Your chosen fire name will be used for download's filename

# Bounding Box syntax: "LowerLeft_Longitude,LowerLeft_Latitude,UpperRight_Longitude,UpperRight_Latitude,'EPSG:Code'"
LL_lon = -116.93191
LL_lat = 32.56482
UR_lon = -116.81826
UR_lat = 32.67451
bbox = f"{LL_lon},{LL_lat},{UR_lon},{UR_lat},'EPSG:4326'"  # For a complete CA BBOX, enter: "-124.5,32.45,-114.0,42.10,'EPSG:4326'"
map_center = [(LL_lat+UR_lat)/2.0, (LL_lon+UR_lon)/2.0]

# Specify a datetime & epoch (yyyy, m, d, h, m, s)
dt_start = datetime(2025, 1, 22, 0, 0, 1)    # Note: the first available VIIRS detection starts from (2016, 8, 11, 1, 0, 0)
dt_end = datetime(2025, 2, 1, 23, 59, 59)   # Note: Large datetime ranges (ex: more than 1 year) may overtax your computer's resources

# ==================================

# %%
# Convert datetime to epoch
epoch_start = int(dt_start.timestamp())
epoch_end = int(dt_end.timestamp())

# GeoServer WFS URL configuration
url = "https://firemap.sdsc.edu/geoserver/wfs"
params = {
    'service': 'WFS',
    'version': '1.0.0',
    'request': 'GetFeature',
    'maxFeatures': '100000',
    'exceptions': 'application/json',
    'typeName': 'WIFIRE:view_viirs_iband',
    'CQL_FILTER': f'epoch_time BETWEEN {epoch_start} AND {epoch_end} AND BBOX(location,{bbox})',
    'outputFormat': 'application/json'
}

# Request the data
r = requests.get(url, params=params, timeout=60)
if r.status_code != 200:
    print(r.text)
    sys.exit(1)

j = r.json()
f = j.get("features", [])

if not f:
    raise ValueError(
        f"No VIIRS dections found for '{fire_name}'.\n"
        f"Check that the datetime range is valid.\n"
        f"Hint: the first available VIIRS detection starts from 2016-08-11T09:20:00Z"
    )

print(f"✓ Found {len(f)} detections \n")

# View the JSON
print(json.dumps(j,indent=2))   # WARNING: Large datetime ranges may overtax your computer's resources
# Out:
# ✓ Found 190 detections
#
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f85",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87519,
#           32.61786
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 336.48,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 310.2,
#         "frp": 27.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f86",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90037,
#           32.63789
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 301.68,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.45,
#         "frp": 0.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f87",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89534,
#           32.63693
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 300.41,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.52,
#         "frp": 1.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f88",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89036,
#           32.63597
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 301.59,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.22,
#         "frp": 1.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f89",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88537,
#           32.635
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 304.79,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.56,
#         "frp": 0.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8a",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88039,
#           32.63404
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 299.65,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.06,
#         "frp": 0.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8b",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90621,
#           32.63523
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 301.38,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.29,
#         "frp": 0.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8c",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90123,
#           32.63427
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 309.6,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.14,
#         "frp": 0.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8d",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89127,
#           32.63235
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 314.86,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.09,
#         "frp": 1.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8e",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88631,
#           32.63139
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 316.09,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.21,
#         "frp": 0.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f8f",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88138,
#           32.63044
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 309.96,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.63,
#         "frp": 0.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f90",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87654,
#           32.62951
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 303.28,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.88,
#         "frp": 1.24,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f91",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89225,
#           32.62874
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 354.19,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 295.27,
#         "frp": 56.43,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f92",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88246,
#           32.62685
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 340.59,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 294.04,
#         "frp": 57.73,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f93",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91212,
#           32.63258
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 303.13,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.96,
#         "frp": 1.49,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f94",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87768,
#           32.62593
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 316.09,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.74,
#         "frp": 4.02,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f95",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87291,
#           32.62501
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 302.5,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.96,
#         "frp": 4.02,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f96",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90807,
#           32.62801
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 350.64,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 300.18,
#         "frp": 89.92,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f97",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90308,
#           32.62704
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 343.38,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 321.29,
#         "frp": 89.92,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f98",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89817,
#           32.62609
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 349.33,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 310.07,
#         "frp": 56.43,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f99",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89325,
#           32.62514
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 354.22,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 304.13,
#         "frp": 56.43,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9a",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88837,
#           32.6242
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 355.62,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 301.69,
#         "frp": 57.73,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9b",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88354,
#           32.62327
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 355.95,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 301.1,
#         "frp": 57.73,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9c",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87873,
#           32.62234
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 341.26,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 292.39,
#         "frp": 4.02,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9d",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91303,
#           32.62896
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 308.41,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.82,
#         "frp": 1.49,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9e",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87399,
#           32.62143
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 317.94,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.65,
#         "frp": 4.02,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f9f",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86919,
#           32.6205
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 302.68,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.21,
#         "frp": 1.68,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa0",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90907,
#           32.6244
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 333.77,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.14,
#         "frp": 15.8,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa1",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90414,
#           32.62345
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 353.11,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 317.04,
#         "frp": 15.8,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa2",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89922,
#           32.6225
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 351.94,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 311.24,
#         "frp": 18.82,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa3",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89432,
#           32.62156
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 348.47,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 294.97,
#         "frp": 18.82,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa4",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88951,
#           32.62062
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 343.69,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 293.77,
#         "frp": 7.27,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa5",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88467,
#           32.61969
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 348.35,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 293.56,
#         "frp": 7.27,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa6",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87988,
#           32.61877
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 350.48,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 298.41,
#         "frp": 27.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa7",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87052,
#           32.61696
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 324.04,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.57,
#         "frp": 6.22,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa8",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91402,
#           32.62536
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 303.16,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.36,
#         "frp": 0.87,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fa9",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86553,
#           32.616
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 298.8,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.17,
#         "frp": 6.22,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4faa",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90519,
#           32.61987
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 345.12,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 291.3,
#         "frp": 15.8,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fab",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90028,
#           32.61892
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 351.9,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 313.14,
#         "frp": 18.82,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fac",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89542,
#           32.61797
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 347.78,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 296.07,
#         "frp": 18.82,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fad",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89055,
#           32.61703
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 346.75,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 295.15,
#         "frp": 7.27,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fae",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88571,
#           32.6161
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 340.7,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 291.57,
#         "frp": 7.27,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4faf",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88096,
#           32.61518
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 346.41,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 291.54,
#         "frp": 27.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb0",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87633,
#           32.61429
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 350.71,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 291.52,
#         "frp": 27.23,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb1",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87178,
#           32.61341
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 349.95,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 291.58,
#         "frp": 6.22,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb2",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86684,
#           32.61246
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 333.47,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 289.23,
#         "frp": 6.22,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb3",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86178,
#           32.61148
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 340.27,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 297.83,
#         "frp": 16.43,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb4",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91501,
#           32.62176
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 299.95,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 283.89,
#         "frp": 0.87,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb5",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91012,
#           32.62082
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 309.41,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.81,
#         "frp": 15.8,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb6",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85711,
#           32.61057
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 312.57,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 287.16,
#         "frp": 16.43,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb7",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91037,
#           32.62835
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 335.4,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 286.99,
#         "frp": 3.9,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb8",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.9054,
#           32.62741
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 346.49,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 312.33,
#         "frp": 47.25,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fb9",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90047,
#           32.62648
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 346.11,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 318.66,
#         "frp": 47.25,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fba",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89555,
#           32.62556
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 353.1,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 304.45,
#         "frp": 23.55,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fbb",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89062,
#           32.62463
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 354.75,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 300.97,
#         "frp": 23.55,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fbc",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.8858,
#           32.62372
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 356.28,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 298.81,
#         "frp": 20.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fbd",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88094,
#           32.62281
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 354.5,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 299.31,
#         "frp": 20.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fbe",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87614,
#           32.62191
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 324.25,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.85,
#         "frp": 22.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fbf",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91535,
#           32.62928
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 298.14,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.81,
#         "frp": 3.9,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc0",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87139,
#           32.62101
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 310.83,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 285.95,
#         "frp": 22.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc1",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90645,
#           32.62382
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 348.91,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 297.22,
#         "frp": 47.25,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc2",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90151,
#           32.62289
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 348.94,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 322.14,
#         "frp": 47.25,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc3",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.8966,
#           32.62197
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 352.58,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 298.88,
#         "frp": 23.55,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc4",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89175,
#           32.62105
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 344.91,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 294.5,
#         "frp": 23.55,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc5",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.8869,
#           32.62014
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 346.99,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 293.92,
#         "frp": 20.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc6",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88208,
#           32.61922
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 352.53,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 297.98,
#         "frp": 20.91,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc7",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87732,
#           32.61833
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 354.76,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 295.72,
#         "frp": 22.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc8",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87265,
#           32.61745
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 332.68,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 303.28,
#         "frp": 22.76,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fc9",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91635,
#           32.62569
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 297.87,
#         "scan": 0.48,
#         "track": 0.4,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T09:49:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 284.27,
#         "frp": 3.9,
#         "daynight": "N"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4fca",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.91138,
#           32.62475
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39076427.7450521,
#         "epoch_time": 1737712140,
#         "bright_ti4": 310.31,
#         "scan": 0.48,
#         "track": 0.4,
# ...
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89239,
#           32.60649
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 328.74,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 297.62,
#         "frp": 9.59,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_502d",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.89788,
#           32.60587
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 349.05,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 310.1,
#         "frp": 42.94,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_502e",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.9034,
#           32.60524
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 337.78,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 305.23,
#         "frp": 42.94,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_502f",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86603,
#           32.61335
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 340.08,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 299.84,
#         "frp": 9.24,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5030",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.9036,
#           32.6091
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 348.53,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 308.15,
#         "frp": 16,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5031",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85558,
#           32.61842
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 347.42,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 299.95,
#         "frp": 20.43,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5032",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86069,
#           32.61784
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 346.75,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 301.41,
#         "frp": 20.43,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5033",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86617,
#           32.61722
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 346.67,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 303.59,
#         "frp": 9.24,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5034",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90384,
#           32.61295
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 345.97,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 303.72,
#         "frp": 16,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5035",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90936,
#           32.61233
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 328.52,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "low",
#         "version": "2.0NRT",
#         "bright_ti5": 299.52,
#         "frp": 7.13,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5036",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.86098,
#           32.6217
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 344.59,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 304.12,
#         "frp": 17.93,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5037",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.87193,
#           32.62046
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 331.05,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 299.67,
#         "frp": 3.03,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5038",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90425,
#           32.61679
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 352.89,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 303.77,
#         "frp": 13.26,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5039",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.90978,
#           32.61616
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 331.53,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 298.98,
#         "frp": 5.74,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503a",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85593,
#           32.62227
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 356.43,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "low",
#         "version": "2.0NRT",
#         "bright_ti5": 297.32,
#         "frp": 17.93,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503b",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85143,
#           32.62667
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 348.15,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 299.73,
#         "frp": 17,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503c",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85638,
#           32.62611
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 343.18,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 302.68,
#         "frp": 17.93,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503d",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.85191,
#           32.6344
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 333.45,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 297.49,
#         "frp": 4.8,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503e",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.8521,
#           32.63827
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 39035687.7450521,
#         "epoch_time": 1737752880,
#         "bright_ti4": 343.93,
#         "scan": 0.52,
#         "track": 0.42,
#         "acq_date": "2025-01-24Z",
#         "acq_time": "1970-01-01T21:08:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 300.78,
#         "frp": 15.66,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_503f",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88698,
#           32.59298
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 38950367.7450521,
#         "epoch_time": 1737838200,
#         "bright_ti4": 367,
#         "scan": 0.38,
#         "track": 0.36,
#         "acq_date": "2025-01-25Z",
#         "acq_time": "1970-01-01T20:50:00Z",
#         "satellite": "N20",
#         "confidence": "high",
#         "version": "2.0NRT",
#         "bright_ti5": 333.02,
#         "frp": 38.83,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5040",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88293,
#           32.59359
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 38950367.7450521,
#         "epoch_time": 1737838200,
#         "bright_ti4": 341.23,
#         "scan": 0.38,
#         "track": 0.36,
#         "acq_date": "2025-01-25Z",
#         "acq_time": "1970-01-01T20:50:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 300.88,
#         "frp": 15.01,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5041",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88364,
#           32.59687
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 38950367.7450521,
#         "epoch_time": 1737838200,
#         "bright_ti4": 343.6,
#         "scan": 0.38,
#         "track": 0.36,
#         "acq_date": "2025-01-25Z",
#         "acq_time": "1970-01-01T20:50:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 292.67,
#         "frp": 15.01,
#         "daynight": "D"
#       }
#     },
#     {
#       "type": "Feature",
#       "id": "view_viirs_iband.fid-20d8c1eb_19db0ce87e1_5042",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -116.88768,
#           32.59626
#         ]
#       },
#       "geometry_name": "location",
#       "properties": {
#         "seconds_ago": 38950367.7450521,
#         "epoch_time": 1737838200,
#         "bright_ti4": 355.55,
#         "scan": 0.38,
#         "track": 0.36,
#         "acq_date": "2025-01-25Z",
#         "acq_time": "1970-01-01T20:50:00Z",
#         "satellite": "N20",
#         "confidence": "nominal",
#         "version": "2.0NRT",
#         "bright_ti5": 305.62,
#         "frp": 38.83,
#         "daynight": "D"
#       }
#     }
#   ],
#   "totalFeatures": 190,
#   "numberMatched": 190,
#   "numberReturned": 190,
#   "timeStamp": "2026-04-21T16:22:47.793Z",
#   "crs": {
#     "type": "name",
#     "properties": {
#       "name": "urn:ogc:def:crs:EPSG::4326"
#     }
#   }
# }

# %%
# # For full Traceback 
# %tb

# %% [markdown]
# Previewing the JSON response in GIS

# %%
# Create map object
m = folium.Map(location=map_center, tiles='cartodbpositron', zoom_start=11)

# Add 375m Radius Circle Marker for GeoJson features
features = folium.features.GeoJson(j,
    marker=folium.Circle(
        radius=187.5, # Radius in meters
        fill=True,
        fill_color="blue",
        fill_opacity=0.2),
        tooltip = folium.GeoJsonTooltip(
            fields=['acq_date', 'confidence', 'daynight'])
).add_to(m)

# Preview map
m   # WARNING: Large datetime ranges may overtax your computer's resources
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5434405b2b288308df4758ad2b256e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5434405b2b288308df4758ad2b256e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5434405b2b288308df4758ad2b256e8 = L.map(
#                 &quot;map_a5434405b2b288308df4758ad2b256e8&quot;,
#                 {
#                     center: [32.619665, -116.875085],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84b34611caa59b8833bdfad514fe8da7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84b34611caa59b8833bdfad514fe8da7.addTo(map_a5434405b2b288308df4758ad2b256e8);
#
#
#         function geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 187.5,
# };
#
#             return new L.circle(latlng, opts)
#         }
#
#         function geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb = L.geoJson(null, {
#                 onEachFeature: geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_onEachFeature,
#
#                 pointToLayer: geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_add (data) {
#             geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb
#                 .addData(data);
#         }
#             geo_json_36fa826a99ce69f45d5b6fecb6f6cdfb_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::4326&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-116.87519, 32.61786], &quot;type&quot;: &quot;Point&quot;}, &quot;geometry_name&quot;: &quot;location&quot;, &quot;id&quot;: &quot;view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f85&quot;, &quot;properties&quot;: {&quot;acq_date&quot;: &quot;2025-01-24Z&quot;, &quot;acq_time&quot;: &quot;1970-01-01T09:49:00Z&quot;, &quot;bright_ti4&quot;: 336.48, &quot;bright_ti5&quot;: 310.2, &quot;confidence&quot;: &quot;nominal&quot;, &quot;daynight&quot;: &quot;N&quot;, &quot;epoch_time&quot;: 1737712140, &quot;frp&quot;: 27.23, &quot;satellite&quot;: &quot;N20&quot;, &quot;scan&quot;: 0.48, &quot;seconds_ago&quot;: 39076427.7450521, &quot;track&quot;: 0.4, &quot;version&quot;: &quot;2.0NRT&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-116.90037, 32.63789], &quot;type&quot;: &quot;Point&quot;}, &quot;geometry_name&quot;: &quot;location&quot;, &quot;id&quot;: &quot;view_viirs_iband.fid-20d8c1eb_19db0ce87e1_4f86&quot;, &quot;properties&quot;: {&quot;acq_date&quot;: &quot;2025-01-24Z&quot;, &quot;acq_time&quot;: &quot;1970-01-01T09:49:00Z&quot;, &quot;bright_ti4&quot;: 301.68, &quot;bright_ti5&quot;: 285.45, &quot;confidence&quot;: &quot;nominal&quot;, &quot;daynight&quot;: &quot;N&quot;, &quot;epoch_time&quot;: 1737712140, &quot;frp&quot;: 0.76, &quot;satellite&quot;: &quot;N20&quot;, &quot;scan&quot;: 0.48, &quot;seconds_ago&quot;: 39076427.7450521, &quot;track&quot;: 0.4, &quot;version&quot;: &quot;2.0NRT&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-116.89534, 32.63693], &quot;type&quot;: &quot;Point&quot;}, &quot;geometry_name&quot;: &quot;location&quot;

# %% [markdown]
# Create Output Filename & Directory

# %%
# Set Output folder & filename prefix
filename = fire_name.replace(" ", "_")
os.makedirs(f"./Fires/{filename}", exist_ok=True)

print(filename)

# %% [markdown]
# Getting VIIRS JSON

# %%
# GeoServer WFS URL JSON configuration
url = "https://firemap.sdsc.edu/geoserver/wfs"
params = {
    'service': 'WFS',
    'version': '1.0.0',
    'request': 'GetFeature',
    'maxFeatures': '100000',
    'exceptions': 'application/json',
    'typeName': 'WIFIRE:view_viirs_iband',
    'CQL_FILTER': f'epoch_time BETWEEN {epoch_start} AND {epoch_end} AND BBOX(location,{bbox})',
    'outputFormat': 'application/json'
}

r = requests.get(url, params=params, timeout=60)
if r.status_code != 200:
    print(r.text)
    sys.exit(1)
elif r.status_code == 200:
    j = r.json()    
    with open(f"./Fires/{filename}/{filename}_viirs.json", "w", encoding="utf-8") as file:
        json.dump(j, file)
    print("JSON saved successfully.")
else:
    print("Error:", r.status_code, r.text)

# %% [markdown]
# Getting VIIRS CSV

# %%
# # GeoServer WFS URL CSV configuration
# url = "https://firemap.sdsc.edu/geoserver/wfs"
# params = {
#     'service': 'WFS',
#     'version': '1.0.0',
#     'request': 'GetFeature',
#     'maxFeatures': '100000',
#     'exceptions': 'application/json',
#     'typeName': 'WIFIRE:view_viirs_iband',
#     'CQL_FILTER': f'epoch_time BETWEEN {epoch_start} AND {epoch_end} AND BBOX(location,{bbox})',
#     'outputFormat': 'csv'
# }

# r = requests.get(url, params=params, timeout=60)
# if r.status_code != 200:
#     print(r.text)
#     sys.exit(1)
# elif r.status_code == 200:
#     with open(f"./Fires/{filename}/{filename}_viirs.csv", "wb") as f:
#         f.write(r.content)
#     print("CSV saved successfully.")
# else:
#     print("Error:", r.status_code, r.text)

# %% [markdown]
# Getting VIIRS Shapefiles

# %%
# # GeoServer WFS URL CSV configuration
# url = "https://firemap.sdsc.edu/geoserver/wfs"
# params = {
#     'service': 'WFS',
#     'version': '1.0.0',
#     'request': 'GetFeature',
#     'maxFeatures': '100000',
#     'exceptions': 'application/json',
#     'typeName': 'WIFIRE:view_viirs_iband',
#     'CQL_FILTER': f'epoch_time BETWEEN {epoch_start} AND {epoch_end} AND BBOX(location,{bbox})',
#     'outputFormat': 'shape-zip'
# }

# r = requests.get(url, params=params, timeout=60)
# if r.status_code != 200:
#     print(r.text)
#     sys.exit(1)
# elif r.status_code == 200:
#     with open(f"./Fires/{filename}/{filename}_viirs.zip", "wb") as f:
#         for chunk in r.iter_content(chunk_size=1024*1024):
#             f.write(chunk)
#     print("Shapefile ZIP saved successfully.")
# else:
#     print("Error:", r.status_code, r.text)
